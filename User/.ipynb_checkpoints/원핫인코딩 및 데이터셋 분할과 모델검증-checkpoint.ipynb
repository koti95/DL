# %%
import pandas as pd
import os
os.chdir('D:/user/User/pydata')
data = pd.read_csv('vote.csv', encoding='utf-8')
data.head()
# Out:
#    gender  region  edu  income  age  score_gov  score_progress  \
# 0       1       4    3       3    3          2               2
# 1       1       5    2       3    3          2               4
# 2       1       3    1       2    4          1               3
# 3       2       1    2       1    3          5               4
# 4       1       1    1       2    4          4               3
#
#    score_intention  vote  parties
# 0              4.0     1        2
# 1              3.0     0        3
# 2              2.8     1        4
# 3              2.6     1        1
# 4              2.4     1        1

# %%
X1 = data[['gender','region']]
XY = data[['edu','income','age','score_gov','score_progress','score_intention','vote',
          'parties']]
XY2 = data.iloc[:,2:]
XY2
# Out:
#      edu  income  age  score_gov  score_progress  score_intention  vote  \
# 0      3       3    3          2               2              4.0     1
# 1      2       3    3          2               4              3.0     0
# 2      1       2    4          1               3              2.8     1
# 3      2       1    3          5               4              2.6     1
# 4      1       2    4          4               3              2.4     1
# ..   ...     ...  ...        ...             ...              ...   ...
# 206    1       4    4          3               3              1.8     1
# 207    2       1    2          3               4              2.6     1
# 208    2       1    2          3               3              2.6     1
# 209    2       3    4          3               2              4.0     1
# 210    2       2    2          3               3              3.8     1
#
#      parties
# 0          2
# 1          3
# 2          4
# 3          1
# 4          1
# ..       ...
# ...

# %%
X1['gender'] = X1['gender'].replace([1,2], ['male','female' ])
X1['region'] = X1['region'].replace([1,2,3,4,5], ['Sudo','Chungcheung','Honam',
                                                  'Youngnam','Others' ])
X1
# Out:
# <ipython-input-16-21576a8d467c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1['gender'] = X1['gender'].replace([1,2], ['male','female' ])
# <ipython-input-16-21576a8d467c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1['region'] = X1['region'].replace([1,2,3,4,5], ['Sudo','Chungcheung','Honam',
#      gender       region
# 0      male     Youngnam
# 1      male       Others
# 2      male        Honam
# 3    female         Sudo
# 4      male         Sudo
# ...

# %%
X1_dum = pd.get_dummies(X1)
X1_dum.head()
# Out:
#    gender_female  gender_male  region_Chungcheung  region_Honam  \
# 0              0            1                   0             0
# 1              0            1                   0             0
# 2              0            1                   0             1
# 3              1            0                   0             0
# 4              0            1                   0             0
#
#    region_Others  region_Sudo  region_Youngnam
# 0              0            0                1
# 1              1            0                0
# 2              0            0                0
# 3              0            1                0
# 4              0            1                0

# %%
Fvote = pd.concat([X1_dum, XY], axis=1)
Fvote.head()
# Out:
#    gender_female  gender_male  region_Chungcheung  region_Honam  \
# 0              0            1                   0             0
# 1              0            1                   0             0
# 2              0            1                   0             1
# 3              1            0                   0             0
# 4              0            1                   0             0
#
#    region_Others  region_Sudo  region_Youngnam  edu  income  age  score_gov  \
# 0              0            0                1    3       3    3          2
# 1              1            0                0    2       3    3          2
# 2              0            0                0    1       2    4          1
# 3              0            1                0    2       1    3          5
# 4              0            1                0    1       2    4          4
#
#    score_progress  score_intention  vote  parties
# 0               2              4.0     1        2
# ...

# %%
Fvote.to_csv('Fvote.csv', index=False, sep=',', encoding='utf-8')

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
data = pd.read_csv('Fvote.csv', encoding='utf-8')
data.head()
# Out:
#    gender_female  gender_male  region_Chungcheung  region_Honam  \
# 0              0            1                   0             0
# 1              0            1                   0             0
# 2              0            1                   0             1
# 3              1            0                   0             0
# 4              0            1                   0             0
#
#    region_Others  region_Sudo  region_Youngnam  edu  income  age  score_gov  \
# 0              0            0                1    3       3    3          2
# 1              1            0                0    2       3    3          2
# 2              0            0                0    1       2    4          1
# 3              0            1                0    2       1    3          5
# 4              0            1                0    1       2    4          4
#
#    score_progress  score_intention  vote  parties
# 0               2              4.0     1        2
# ...

# %%
#방법 1: 특성이름으로 데이터셋
#방법 2: 위치값으로 데이터셋 나누기
X=data[data.columns[1:14]]
#방법 3 : iloc 함수로 데이터셋 나누기
X=data.iloc[:,1:14]
#방법 3 : loc 함수로 데이터셋 나누기
X=data.loc[:,'gender_female':'score_intention']

# %%
y=data[['vote']]

# %% [markdown]
# ## train - test 데이터셋 나누기

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (158, 13)
# (53, 13)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#랜덤없는 교차검증 : cross_val_score
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X_train, y_train, cv=5)
print('테스트셋 정확도:', scores)
print('정확도 평균:', scores.mean())
# Out:
# 테스트셋 정확도: [0.71875    0.6875     0.8125     0.58064516 0.80645161]
# 정확도 평균: 0.7211693548387096

# %%
#랜덤 있는 교차 검증:K-Fold
from sklearn.model_selection import KFold
kfold=KFold(n_splits=5, shuffle=True, random_state=42)
score = cross_val_score(model, X_train, y_train, cv=kfold)
print("5개의 폴드 정확도:", scores)
# Out:
# 5개의 폴드 정확도: [0.71875    0.6875     0.8125     0.58064516 0.80645161]

# %%
# 임의 분할 교차검증
from sklearn.model_selection import ShuffleSplit
shuffle_split=ShuffleSplit(test_size=0.5, train_size=0.5,random_state=42)
scores = cross_val_score(model, X_train, y_train, cv=shuffle_split)
print("교차검증 정확도:", scores.mean())
# Out:
# 교차검증 정확도: 0.6987341772151898
