# %%
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import numpy as np
import random as rd

# %%
CCTV_cluster = pd.read_csv('G:/Python/EDA/회귀분석_ZZIN.csv', encoding='cp949')
CCTV_cluster_index = CCTV_cluster.set_index("행정동")
CCTV_cluster_index.head(5)
# Out:
#         y_단속건수  x1_주차가능대수  x2_자동차등록대수        x3_면적  x4_주차장수
# 행정동
# 남부민동      1919        823        3744  1084073.586       10
# 동대신동1가     103        192        1466   231596.538        4
# 동대신동2가     387        167        2001   433466.519        6
# 동대신동3가     585        954        2040  1471082.808        7
# 부민동1가       28         80         373    44150.328        3

# %%
plt.scatter(CCTV_cluster_index.iloc[:,1],CCTV_cluster_index.iloc[:,0],c='black',label='단속건수')
plt.xlabel('주차가능대수')
plt.ylabel('단속건수')
plt.legend()
plt.title('주차가능대수에 따른 단속건수')
plt.show()

# %%
data_points = CCTV_cluster_index.values

# %%
kmeans = KMeans(n_clusters=4).fit(data_points)

# %%
kmeans.labels_
# Out:
# array([3, 2, 0, 3, 2, 2, 2, 2, 2, 2, 0, 1, 2, 0, 1, 0, 2, 2, 2, 2, 2, 2,
#        2, 2])

# %%
CCTV_cluster_index['cluster_id'] = kmeans.labels_

# %%
CCTV_cluster_index['cluster_id']
# Out:
# 행정동
# 남부민동      3
# 동대신동1가    2
# 동대신동2가    0
# 동대신동3가    3
# 부민동1가     2
# 부민동2가     2
# 부민동3가     2
# 부용동1가     2
# 부용동2가     2
# 서대신동1가    2
# 서대신동2가    0
# 서대신동3가    1
# 아미동1가     2
# 아미동2가     0
# 암남동       1
# 초장동       0
# 충무동1가     2
# 충무동2가     2
# 충무동3가     2
# 토성동1가     2
# 토성동2가     2
# 토성동3가     2
# 토성동4가     2
# 토성동5가     2
# Name: cluster_id, dtype: int32

# %%
sns.lmplot('x1_주차가능대수','y_단속건수', data=CCTV_cluster_index, fit_reg = False,
          scatter_kws={"s":150},
          hue="cluster_id")
plt.title('kmean')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'kmean')

# %%
CCTV_cluster_index.groupby(CCTV_cluster_index['cluster_id']).mean()
# Out:
#                y_단속건수  x1_주차가능대수  x2_자동차등록대수         x3_면적  x4_주차장수
# cluster_id
# 0           1771.0000   171.0000   1591.7500  4.981922e+05   5.5000
# 1           3172.0000  3271.0000   5049.0000  4.116365e+06  14.0000
# 2            409.8125   200.4375    532.0625  7.799527e+04   2.4375
# 3           1252.0000   888.5000   2892.0000  1.277578e+06   8.5000

# %%
CCTV_cluster_index1= CCTV_cluster_index['cluster_id'] == 0
CCTV_cluster_index2 = CCTV_cluster_index[CCTV_cluster_index1]
CCTV_cluster_index2
# Out:
#         y_단속건수  x1_주차가능대수  x2_자동차등록대수       x3_면적  x4_주차장수  cluster_id
# 행정동
# 동대신동2가     387        167        2001  433466.519        6           0
# 서대신동2가     718        280        2343  433698.759        4           0
# 아미동2가      423        193        1167  682339.062        7           0
# 초장동       5556         44         856  443264.565        5           0

# %%
CCTV_cluster_index1= CCTV_cluster_index['cluster_id'] == 1
CCTV_cluster_index2 = CCTV_cluster_index[CCTV_cluster_index1]
CCTV_cluster_index2
# Out:
#         y_단속건수  x1_주차가능대수  x2_자동차등록대수        x3_면적  x4_주차장수  cluster_id
# 행정동
# 서대신동3가    2463        685        5248  4539951.390       10           1
# 암남동       3881       5857        4850  3692778.032       18           1

# %%
CCTV_cluster_index1= CCTV_cluster_index['cluster_id'] == 3
CCTV_cluster_index2 = CCTV_cluster_index[CCTV_cluster_index1]
CCTV_cluster_index2
# Out:
#         y_단속건수  x1_주차가능대수  x2_자동차등록대수        x3_면적  x4_주차장수  cluster_id
# 행정동
# 남부민동      1919        823        3744  1084073.586       10           3
# 동대신동3가     585        954        2040  1471082.808        7           3

# %%
CCTV_cluster_index1= CCTV_cluster_index['cluster_id'] == 2
CCTV_cluster_index2 = CCTV_cluster_index[CCTV_cluster_index1]
CCTV_cluster_index2
# Out:
#         y_단속건수  x1_주차가능대수  x2_자동차등록대수       x3_면적  x4_주차장수  cluster_id
# 행정동
# 동대신동1가     103        192        1466  231596.538        4           2
# 부민동1가       28         80         373   44150.328        3           2
# 부민동2가       35       1252          67   40229.666        4           2
# 부민동3가       17         99         933  184599.429        5           2
# 부용동1가      469        149         405   38742.335        1           2
# 부용동2가       15         58         304  105050.039        3           2
# 서대신동1가    3289        134        1861  194345.327        3           2
# 아미동1가     1230        496         391   39792.351        1           2
# 충무동1가      121        357         404   98067.491        8           2
# 충무동2가       30          5         226   31258.145        0           2
# 충무동3가       17         52         143   27008.864        0           2
# 토성동1가     1148        124         945   62443.087        3           2
# ...
